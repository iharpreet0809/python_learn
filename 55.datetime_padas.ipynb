# %%
# datetime module

# %%
import pandas as pd

# %%
data=pd.read_csv('tv_shows.csv')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes',
#        'Netflix', 'Hulu', 'Prime Video', 'Disney+', 'Type'],
#       dtype='object')

# %%
df=data[['Title', 'Year', 'IMDb',
       'Netflix', 'Hulu', 'Prime Video', 'Disney+']]

# %%
len(df)
# Out:
# 5368

# %%
d=df[:100]

# %%
d
# Out:
#                            Title  Year    IMDb  Netflix  Hulu  Prime Video  \
# 0                   Breaking Bad  2008  9.4/10        1     0            0
# 1                Stranger Things  2016  8.7/10        1     0            0
# 2                Attack on Titan  2013  9.0/10        1     1            0
# 3               Better Call Saul  2015  8.8/10        1     0            0
# 4                           Dark  2017  8.8/10        1     0            0
# ..                           ...   ...     ...      ...   ...          ...
# 95           Halt and Catch Fire  2014  8.4/10        1     0            0
# 96  Monty Python's Flying Circus  1969  8.8/10        1     0            0
# 97                    After Life  2019  8.4/10        1     0            0
# 98                     Riverdale  2017  6.8/10        1     1            0
# 99                     Big Mouth  2017  7.9/10        1     0            0
#
#     Disney+
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
dates=pd.date_range('20211201','20220120')

# %%
dates
# Out:
# DatetimeIndex(['2021-12-01', '2021-12-02', '2021-12-03', '2021-12-04',
#                '2021-12-05', '2021-12-06', '2021-12-07', '2021-12-08',
#                '2021-12-09', '2021-12-10', '2021-12-11', '2021-12-12',
#                '2021-12-13', '2021-12-14', '2021-12-15', '2021-12-16',
#                '2021-12-17', '2021-12-18', '2021-12-19', '2021-12-20',
#                '2021-12-21', '2021-12-22', '2021-12-23', '2021-12-24',
#                '2021-12-25', '2021-12-26', '2021-12-27', '2021-12-28',
#                '2021-12-29', '2021-12-30', '2021-12-31', '2022-01-01',
#                '2022-01-02', '2022-01-03', '2022-01-04', '2022-01-05',
#                '2022-01-06', '2022-01-07', '2022-01-08', '2022-01-09',
#                '2022-01-10', '2022-01-11', '2022-01-12', '2022-01-13',
#                '2022-01-14', '2022-01-15', '2022-01-16', '2022-01-17',
#                '2022-01-18', '2022-01-19', '2022-01-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
date=pd.date_range('20200301',periods=100)

# %%
date
# Out:
# DatetimeIndex(['2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#                '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08',
#                '2020-03-09', '2020-03-10', '2020-03-11', '2020-03-12',
#                '2020-03-13', '2020-03-14', '2020-03-15', '2020-03-16',
#                '2020-03-17', '2020-03-18', '2020-03-19', '2020-03-20',
#                '2020-03-21', '2020-03-22', '2020-03-23', '2020-03-24',
#                '2020-03-25', '2020-03-26', '2020-03-27', '2020-03-28',
#                '2020-03-29', '2020-03-30', '2020-03-31', '2020-04-01',
#                '2020-04-02', '2020-04-03', '2020-04-04', '2020-04-05',
#                '2020-04-06', '2020-04-07', '2020-04-08', '2020-04-09',
#                '2020-04-10', '2020-04-11', '2020-04-12', '2020-04-13',
#                '2020-04-14', '2020-04-15', '2020-04-16', '2020-04-17',
#                '2020-04-18', '2020-04-19', '2020-04-20', '2020-04-21',
# ...

# %%
d.index=date

# %%
d
# Out:
#                                    Title  Year    IMDb  Netflix  Hulu  \
# 2020-01-01                  Breaking Bad  2008  9.4/10        1     0
# 2020-01-02               Stranger Things  2016  8.7/10        1     0
# 2020-01-03               Attack on Titan  2013  9.0/10        1     1
# 2020-01-04              Better Call Saul  2015  8.8/10        1     0
# 2020-01-05                          Dark  2017  8.8/10        1     0
# ...                                  ...   ...     ...      ...   ...
# 2020-04-05           Halt and Catch Fire  2014  8.4/10        1     0
# 2020-04-06  Monty Python's Flying Circus  1969  8.8/10        1     0
# 2020-04-07                    After Life  2019  8.4/10        1     0
# 2020-04-08                     Riverdale  2017  6.8/10        1     1
# 2020-04-09                     Big Mouth  2017  7.9/10        1     0
#
#             Prime Video  Disney+
# 2020-01-01            0        0
# 2020-01-02            0        0
# ...

# %%
d.loc['2020-03-10']
# Out:
# Title          How to Get Away with Murder
# Year                                  2014
# IMDb                                8.1/10
# Netflix                                  1
# Hulu                                     1
# Prime Video                              0
# Disney+                                  0
# Name: 2020-03-10 00:00:00, dtype: object

# %%
d['2020-01-01':'2020-01-15']
# Out:
#                                  Title  Year    IMDb  Netflix  Hulu  \
# 2020-01-01                Breaking Bad  2008  9.4/10        1     0
# 2020-01-02             Stranger Things  2016  8.7/10        1     0
# 2020-01-03             Attack on Titan  2013  9.0/10        1     1
# 2020-01-04            Better Call Saul  2015  8.8/10        1     0
# 2020-01-05                        Dark  2017  8.8/10        1     0
# 2020-01-06  Avatar: The Last Airbender  2005  9.3/10        1     0
# 2020-01-07              Peaky Blinders  2013  8.8/10        1     0
# 2020-01-08            The Walking Dead  2010  8.2/10        1     0
# 2020-01-09                Black Mirror  2011  8.8/10        1     0
# 2020-01-10          The Queen's Gambit  2020  8.6/10        1     0
# 2020-01-11                  Mindhunter  2017  8.6/10        1     0
# 2020-01-12                   Community  2009  8.5/10        1     1
# 2020-01-13                      Narcos  2015  8.8/10        1     0
# ...

# %%
d['date']=date
# Out:
# c:\users\rmani\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
d
# Out:
#                                    Title  Year    IMDb  Netflix  Hulu  \
# 2020-03-01                  Breaking Bad  2008  9.4/10        1     0
# 2020-03-02               Stranger Things  2016  8.7/10        1     0
# 2020-03-03               Attack on Titan  2013  9.0/10        1     1
# 2020-03-04              Better Call Saul  2015  8.8/10        1     0
# 2020-03-05                          Dark  2017  8.8/10        1     0
# ...                                  ...   ...     ...      ...   ...
# 2020-06-04           Halt and Catch Fire  2014  8.4/10        1     0
# 2020-06-05  Monty Python's Flying Circus  1969  8.8/10        1     0
# 2020-06-06                    After Life  2019  8.4/10        1     0
# 2020-06-07                     Riverdale  2017  6.8/10        1     1
# 2020-06-08                     Big Mouth  2017  7.9/10        1     0
#
#             Prime Video  Disney+       date  dayofyear
# 2020-03-01            0        0 2020-03-01          1
# ...

# %%
d['dayofyear']=d['date'].dt.dayofyear
# Out:
# c:\users\rmani\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
d
# Out:
#                                    Title  Year    IMDb  Netflix  Hulu  \
# 2020-03-01                  Breaking Bad  2008  9.4/10        1     0
# 2020-03-02               Stranger Things  2016  8.7/10        1     0
# 2020-03-03               Attack on Titan  2013  9.0/10        1     1
# 2020-03-04              Better Call Saul  2015  8.8/10        1     0
# 2020-03-05                          Dark  2017  8.8/10        1     0
# ...                                  ...   ...     ...      ...   ...
# 2020-06-04           Halt and Catch Fire  2014  8.4/10        1     0
# 2020-06-05  Monty Python's Flying Circus  1969  8.8/10        1     0
# 2020-06-06                    After Life  2019  8.4/10        1     0
# 2020-06-07                     Riverdale  2017  6.8/10        1     1
# 2020-06-08                     Big Mouth  2017  7.9/10        1     0
#
#             Prime Video  Disney+       date  dayofyear
# 2020-03-01            0        0 2020-03-01         61
# ...

# %%
d['month']=d['date'].dt.day_name()
# Out:
# c:\users\rmani\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
d.drop('month',inplace=True,axis=1)

# %%
d['day_name']=d['date'].dt.day_name()
# Out:
# c:\users\rmani\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
d
# Out:
#                                    Title  Year    IMDb  Netflix  Hulu  \
# 2020-03-01                  Breaking Bad  2008  9.4/10        1     0
# 2020-03-02               Stranger Things  2016  8.7/10        1     0
# 2020-03-03               Attack on Titan  2013  9.0/10        1     1
# 2020-03-04              Better Call Saul  2015  8.8/10        1     0
# 2020-03-05                          Dark  2017  8.8/10        1     0
# ...                                  ...   ...     ...      ...   ...
# 2020-06-04           Halt and Catch Fire  2014  8.4/10        1     0
# 2020-06-05  Monty Python's Flying Circus  1969  8.8/10        1     0
# 2020-06-06                    After Life  2019  8.4/10        1     0
# 2020-06-07                     Riverdale  2017  6.8/10        1     1
# 2020-06-08                     Big Mouth  2017  7.9/10        1     0
#
#             Prime Video  Disney+       date   day_name
# 2020-03-01            0        0 2020-03-01     Sunday
# ...

# %%
d['dayofmonth']=d['date'].dt.day
#  day ====? month day
# month===> month number
# day_name===> weekdayname
# dayofyear ---> day of year
# Out:
# c:\users\rmani\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
d[:35]
# Out:
#                                        Title  Year    IMDb  Netflix  Hulu  \
# 2020-03-01                      Breaking Bad  2008  9.4/10        1     0
# 2020-03-02                   Stranger Things  2016  8.7/10        1     0
# 2020-03-03                   Attack on Titan  2013  9.0/10        1     1
# 2020-03-04                  Better Call Saul  2015  8.8/10        1     0
# 2020-03-05                              Dark  2017  8.8/10        1     0
# 2020-03-06        Avatar: The Last Airbender  2005  9.3/10        1     0
# 2020-03-07                    Peaky Blinders  2013  8.8/10        1     0
# 2020-03-08                  The Walking Dead  2010  8.2/10        1     0
# 2020-03-09                      Black Mirror  2011  8.8/10        1     0
# 2020-03-10                The Queen's Gambit  2020  8.6/10        1     0
# 2020-03-11                        Mindhunter  2017  8.6/10        1     0
# 2020-03-12                         Community  2009  8.5/10        1     1
# ...

# %%
d['dayofweek']=d['date'].dt.weekday
# Out:
# c:\users\rmani\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
d[(d['day_name']!='Sunday')]
# Out:
#                                    Title  Year    IMDb  Netflix  Hulu  \
# 2020-03-02               Stranger Things  2016  8.7/10        1     0
# 2020-03-03               Attack on Titan  2013  9.0/10        1     1
# 2020-03-04              Better Call Saul  2015  8.8/10        1     0
# 2020-03-05                          Dark  2017  8.8/10        1     0
# 2020-03-06    Avatar: The Last Airbender  2005  9.3/10        1     0
# ...                                  ...   ...     ...      ...   ...
# 2020-06-03                      Manifest  2018  7.2/10        1     1
# 2020-06-04           Halt and Catch Fire  2014  8.4/10        1     0
# 2020-06-05  Monty Python's Flying Circus  1969  8.8/10        1     0
# 2020-06-06                    After Life  2019  8.4/10        1     0
# 2020-06-08                     Big Mouth  2017  7.9/10        1     0
#
#             Prime Video  Disney+       date   day_name  dayofmonth  dayofweek
# ...

# %% [markdown]
# # SQL

# %%
nums=lambda x: x**2

# %%
# lambda argumnet : expression

# %%
nums(10)
# Out:
# 100

# %%
num=lambda x,y: x+y

# %%
num(10,20)
# Out:
# 30

# %%
num(30,60)
# Out:
# 90

# %%
num
# Out:
# <function __main__.<lambda>(x, y)>

# %%
d=lambda a: 'even' if a%2==0 else 'odd'

# %%
d(22)
# Out:
# 'even'

# %%
d(12)
# Out:
# 'even'

# %%
d(11)
# Out:
# 'odd'
