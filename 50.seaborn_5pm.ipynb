# %%
import seaborn as sns

# %%
# distribution
# distplot
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data=np.random.normal(45,5,1000)
plt.style.use('seaborn')

# %%
plt.figure(figsize=(12,5))
sns.distplot(data)
plt.show()
# Out:
# c:\users\rmani\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(data)
# Out:
# [39.26985254 52.17192744 41.38235999 50.0646064  45.39270979 41.40082737
#  44.12537816 46.76980007 45.94246821 41.78258176 50.55327254 47.24927804
#  48.21662474 45.2482325  45.90103952 48.18077821 47.94452319 43.62495132
#  35.93801311 42.51470888 46.56738088 37.73431359 49.83816955 48.33058487
#  40.86967998 42.54933227 41.42641102 47.53313385 41.67567096 40.26295969
#  49.83015649 43.68261055 45.88748692 38.70307742 46.14360321 47.64977137
#  51.16720697 41.73592781 41.22851609 43.31626164 49.26807184 44.72584708
#  37.66439427 43.7019581  52.44753596 44.28340955 43.16590875 47.40977898
#  47.91166618 42.678746   49.73376999 53.37198404 42.49148786 42.89651759
#  45.21863208 41.47096777 42.70603034 36.37144822 49.62570866 42.37106562
#  46.30459881 47.41819511 46.54038845 39.9196773  46.65489458 49.223032
#  44.67061183 50.64105401 48.87451445 41.9987011  41.27136665 44.47017431
#  44.84554835 48.67499866 46.57911158 52.50901017 52.24460503 37.75535545
# ...

# %%
sns.load_dataset?

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(tips['total_bill'])
plt.show()
# Out:
# c:\users\rmani\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips['tip'])
# Out:
# c:\users\rmani\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips,hue='smoker')
plt.savefig('pairplot.png')
plt.show()

# %%
sns.violinplot(x='sex',y='total_bill',hue='day',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x='sex',y='total_bill',data=tips,hue='smoker')
plt.show()

# %%
r=tips[(tips['sex']=='Male') & (tips['smoker']=='Yes')]['total_bill']>46

# %%
r
# Out:
# 56     False
# 58     False
# 60     False
# 61     False
# 62     False
# 63     False
# 69     False
# 76     False
# 80     False
# 83     False
# 90     False
# 95     False
# 96     False
# 97     False
# 98     False
# 105    False
# 106    False
# 107    False
# 138    False
# 170     True
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 187    False
# 189    False
# 190    False
# 192    False
# 193    False
# 194    False
# 196    False
# 199    False
# 200    False
# 204    False
# 206    False
# 207    False
# 208    False
# 210    False
# 211    False
# 216    False
# 217    False
# 218    False
# 220    False
# 222    False
# 224    False
# 230    False
# 231    False
# 234    False
# 236    False
# 237    False
# 241    False
# Name: total_bill, dtype: bool

# %%
for i in r:
    if i:
        print(i)
# Out:
# True

# %%
data=[1,2,3,4,5,6,7,8,9,50]

# %%
sns.boxplot(data)
plt.show()
# Out:
# c:\users\rmani\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(x='smoker',data=tips,hue='sex',color='red')
plt.grid()

# %%
titanic['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
sns.countplot?
