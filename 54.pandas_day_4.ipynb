# %%
import pandas as pd

# %%
import seaborn as sns

# %%
flight=sns.load_dataset('flights')

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flight.pivot(index='month',columns='year',values='passengers')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
df=pd.DataFrame({'city':['mumbai','goa','delhi','jaipur'],'temp':[25,21,15,20]})

# %%
df
# Out:
#      city  temp
# 0  mumbai    25
# 1     goa    21
# 2   delhi    15
# 3  jaipur    20

# %%
df1=pd.DataFrame({'city':['mumbai','delhi','goa','jaipur','agra'],'humidity':[65,71,55,68,80]})

# %%
df1
# Out:
#      city  humidity
# 0  mumbai        65
# 1   delhi        71
# 2     goa        55
# 3  jaipur        68
# 4    agra        80

# %%
df
# Out:
#      city  temp
# 0  mumbai    25
# 1     goa    21
# 2   delhi    15
# 3  jaipur    20

# %%
pd.merge(df,df1,on='city',how='left')
# Out:
#      city  temp  humidity
# 0  mumbai    25        65
# 1     goa    21        55
# 2   delhi    15        71
# 3  jaipur    20        68

# %%
city_data=pd.DataFrame({'city':['mumbai','delhi','goa','jaipur','agra','jaiput','delhi','delhi','jaipur','goa'],'humidity':[65,71,55,68,80,66,54,68,77,63],'temp':[25,21,15,20,33,32,30,28,27,25]})

# %%
city_data
# Out:
#      city  humidity  temp
# 0  mumbai        65    25
# 1   delhi        71    21
# 2     goa        55    15
# 3  jaipur        68    20
# 4    agra        80    33
# 5  jaiput        66    32
# 6   delhi        54    30
# 7   delhi        68    28
# 8  jaipur        77    27
# 9     goa        63    25

# %%
groupby=city_data.groupby('city')

# %%
t=groupby.get_group('delhi')

# %%
groupby.get_group('jaipur')
# Out:
#      city  humidity  temp
# 3  jaipur        68    20
# 8  jaipur        77    27

# %%
for name,value in groupby:
    print(name)
    print(value)
# Out:
# agra
#    city  humidity  temp
# 4  agra        80    33
# delhi
#     city  humidity  temp
# 1  delhi        71    21
# 6  delhi        54    30
# 7  delhi        68    28
# goa
#   city  humidity  temp
# 2  goa        55    15
# 9  goa        63    25
# jaipur
#      city  humidity  temp
# 3  jaipur        68    20
# 8  jaipur        77    27
# jaiput
#      city  humidity  temp
# 5  jaiput        66    32
# mumbai
#      city  humidity  temp
# 0  mumbai        65    25

# %%
t['humidity'][1]=70
# Out:
# c:\users\rmani\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\rmani\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py:3343: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
t
# Out:
#     city  humidity  temp
# 1  delhi        70    21
# 6  delhi        54    30
# 7  delhi        68    28

# %%
city_data
# Out:
#      city  humidity  temp
# 0  mumbai        65    25
# 1   delhi        71    21
# 2     goa        55    15
# 3  jaipur        68    20
# 4    agra        80    33
# 5  jaiput        66    32
# 6   delhi        54    30
# 7   delhi        68    28
# 8  jaipur        77    27
# 9     goa        63    25

# %%
w=list(city_data['city'])

# %%
w
# Out:
# ['mumbai',
#  'delhi',
#  'goa',
#  'jaipur',
#  'agra',
#  'jaiput',
#  'delhi',
#  'delhi',
#  'jaipur',
#  'goa']

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(w,city_data['humidity'])
# Out:
# <BarContainer object of 10 artists>

# %%
city_data.dtypes
# Out:
# city        object
# humidity     int64
# temp         int64
# dtype: object
