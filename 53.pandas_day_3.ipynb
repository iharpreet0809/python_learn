# %%
import pandas as pd

# %%
data=pd.read_csv('titanic.csv')

# %%
data
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df=data[['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
       'fare']]

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare
# 0           0       3    male  22.0      1      0   7.2500
# 1           1       1  female  38.0      1      0  71.2833
# 2           1       3  female  26.0      0      0   7.9250
# 3           1       1  female  35.0      1      0  53.1000
# 4           0       3    male  35.0      0      0   8.0500
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0  13.0000
# 887         1       1  female  19.0      0      0  30.0000
# 888         0       3  female   NaN      1      2  23.4500
# 889         1       1    male  26.0      0      0  30.0000
# 890         0       3    male  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
len(df)
# Out:
# 891

# %%
df['survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
pd.crosstab(df['survived'],df['sex']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='survived'>

# %%
pd.crosstab(df['survived'],df['sex'])
# Out:
# sex       female  male
# survived
# 0             81   468
# 1            233   109

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare
# 0           0       3    male  22.0      1      0   7.2500
# 1           1       1  female  38.0      1      0  71.2833
# 2           1       3  female  26.0      0      0   7.9250
# 3           1       1  female  35.0      1      0  53.1000
# 4           0       3    male  35.0      0      0   8.0500
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0  13.0000
# 887         1       1  female  19.0      0      0  30.0000
# 888         0       3  female   NaN      1      2  23.4500
# 889         1       1    male  26.0      0      0  30.0000
# 890         0       3    male  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
pd.crosstab(df['survived'],df['pclass']).plot(kind='bar')
plt.grid()
plt.ylabel('valaues')
plt.show()

# %%
pd.crosstab(df['sex'],df['pclass'])
# Out:
# pclass    1    2    3
# sex
# female   94   76  144
# male    122  108  347

# %%
d=df[:10]

# %%
d
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500
# 5         0       3    male   NaN      0      0   8.4583
# 6         0       1    male  54.0      0      0  51.8625
# 7         0       3    male   2.0      3      1  21.0750
# 8         1       3  female  27.0      0      2  11.1333
# 9         1       2  female  14.0      1      0  30.0708

# %%
pd.melt(d)
# Out:
#     variable    value
# 0   survived        0
# 1   survived        1
# 2   survived        1
# 3   survived        1
# 4   survived        0
# ..       ...      ...
# 65      fare   8.4583
# 66      fare  51.8625
# 67      fare   21.075
# 68      fare  11.1333
# 69      fare  30.0708
#
# [70 rows x 2 columns]

# %%
df=pd.DataFrame({'name':['a','b','c','d','a'],'course':['python','java','c++','c#','python'],'age':[10,20,21,25,10],'address':['aa','bb','cc','dd','aa']})

# %%
df
# Out:
#   name  course  age address
# 0    a  python   10      aa
# 1    b    java   20      bb
# 2    c     c++   21      cc
# 3    d      c#   25      dd
# 4    e  python   30      dd

# %%
pd.melt(df,id_vars=['name'],value_vars=['course'])
# Out:
#   name variable   value
# 0    a   course  python
# 1    b   course    java
# 2    c   course     c++
# 3    d   course      c#
# 4    e   course  python

# %%
pd.melt(df,id_vars=['name'],value_vars=['course','age'],var_name='info',value_name='data')
# Out:
#   name    info    data
# 0    a  course  python
# 1    b  course    java
# 2    c  course     c++
# 3    d  course      c#
# 4    e  course  python
# 5    a     age      10
# 6    b     age      20
# 7    c     age      21
# 8    d     age      25
# 9    e     age      30

# %%
df
# Out:
#   name  course  age address
# 0    a  python   10      aa
# 1    b    java   20      bb
# 2    c     c++   21      cc
# 3    d      c#   25      dd
# 4    a  python   10      aa

# %%
df.drop_duplicates()
# Out:
#   name  course  age address
# 0    a  python   10      aa
# 1    b    java   20      bb
# 2    c     c++   21      cc
# 3    d      c#   25      dd

# %%
df
# Out:
#   name  course  age address
# 0    a  python   10      aa
# 1    b    java   20      bb
# 2    c     c++   21      cc
# 3    d      c#   25      dd
# 4    a  python   10      aa

# %%
df.unique
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-24917de15bc0> in <module>
# ----> 1 df.unique
#
# c:\users\rmani\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
import numpy as np

# %%
a=np.array([1,2,4,5,2,1])

# %%
a
# Out:
# array([1, 2, 4, 5, 2, 1])

# %%
pd.unique(df['name'])
# Out:
# array(['a', 'b', 'c', 'd'], dtype=object)

# %%
df
# Out:
#   name  course  age address
# 0    a  python   10      aa
# 1    b    java   20      bb
# 2    c     c++   21      cc
# 3    d      c#   25      dd
# 4    a  python   10      aa

# %%
pd.unique(df['course'])
# Out:
# array(['python', 'java', 'c++', 'c#'], dtype=object)

# %%
d
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500
# 5         0       3    male   NaN      0      0   8.4583
# 6         0       1    male  54.0      0      0  51.8625
# 7         0       3    male   2.0      3      1  21.0750
# 8         1       3  female  27.0      0      2  11.1333
# 9         1       2  female  14.0      1      0  30.0708

# %%
pd.unique(d['pclass'])
# Out:
# array([3, 1, 2], dtype=int64)

# %%
d['pclass'].drop_duplicates()
# Out:
# 0    3
# 1    1
# 9    2
# Name: pclass, dtype: int64

# %%
data.sample(n=10)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 359         359         1       3  female   NaN      0      0   7.8792
# 4             4         0       3    male  35.0      0      0   8.0500
# 84           84         1       2  female  17.0      0      0  10.5000
# 720         720         1       2  female   6.0      0      1  33.0000
# 719         719         0       3    male  33.0      0      0   7.7750
# 324         324         0       3    male   NaN      8      2  69.5500
# 477         477         0       3    male  29.0      1      0   7.0458
# 158         158         0       3    male   NaN      0      0   8.6625
# 243         243         0       3    male  22.0      0      0   7.1250
# 352         352         0       3    male  15.0      1      1   7.2292
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# 359        Q   Third  woman       False  NaN   Queenstown   yes   True
# ...

# %%
# date time module
# mysql
# merge
#user define  , map or  lambda
